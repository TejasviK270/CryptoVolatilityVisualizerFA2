# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasviK270/CryptoVolatilityVisualizerFA2/blob/main/Copy_of_Data_Mining_Python_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Path to your file in Google Drive
file_path = '/content/btcusd_1-min_data.csv'

# Load the CSV file into a DataFrame
import pandas as pd
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head(101))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         Timestamp  Open  High   Low  Close  Volume
# 0    1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1    1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2    1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3    1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4    1.325412e+09  4.58  4.58  4.58   4.58     0.0
# ..            ...   ...   ...   ...    ...     ...
# 96   1.325418e+09  4.58  4.58  4.58   4.58     0.0
# 97   1.325418e+09  4.58  4.58  4.58   4.58     0.0
# 98   1.325418e+09  4.58  4.58  4.58   4.58     0.0
# 99   1.325418e+09  4.58  4.58  4.58   4.58     0.0
# 100  1.325418e+09  4.58  4.58  4.58   4.58     0.0
#
# [101 rows x 6 columns]
